# %% [markdown]
# ### Explore Phoenix Vendor Payments from 2014 - 2018

# %%
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker
import seaborn as sns
import datetime
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
files = glob.glob('data/cleaned_data/*.csv')

payments = pd.concat([pd.read_csv(f, dtype={'commitmt_item_name': 'str', 'dept._descrptn': 'str', 'vendor_name': 'str'}) \
                      for f in files], sort=True)

# %%
payments.shape
# Out:
# (2215460, 5)

# %%
payments.dtypes
# Out:
# check/payment_date     object
# commitmt_item_name     object
# dept._descrptn         object
# invoice_net_amt       float64
# vendor_name            object
# dtype: object

# %%
payments.set_index('vendor_name', inplace=True)

# %%
payments.head()
# Out:
#                                 check/payment_date commitmt_item_name  \
# vendor_name
# 3M COMPANY                              2014-01-02        Inventories
# 3M COMPANY                              2014-01-02        Inventories
# 3M COMPANY                              2014-01-02        Inventories
# AGS SAFETY & SUPPLY                     2014-01-02        Inventories
# AMERICAN EUROCOPTER CORPORATION         2014-01-02        Inventories
#
#                                         dept._descrptn  invoice_net_amt
# vendor_name
# 3M COMPANY                       Street Transportation           -34.78
# 3M COMPANY                       Street Transportation           -69.55
# 3M COMPANY                       Street Transportation           -77.00
# AGS SAFETY & SUPPLY                       Public Works             0.01
# AMERICAN EUROCOPTER CORPORATION                 Police            -0.79

# %% [markdown]
# #### Change columns to appropriate data types

# %%
# change Check/Payment Date to datetime format
payments['check/payment_date'] = pd.to_datetime(payments['check/payment_date'])

# %%
payments.dtypes
# Out:
# check/payment_date    datetime64[ns]
# commitmt_item_name            object
# dept._descrptn                object
# invoice_net_amt              float64
# dtype: object

# %% [markdown]
# ### How do payments track year over year, month over month?

# %%
# combine year and month in same column to be able to graph year + month together
payments['year_month'] = payments['check/payment_date'].apply(lambda x: str(x.year) + str(x.month).zfill(2))

# %%
# designate year and month in separate columns to be able to graph these separately
payments['year'] = payments['check/payment_date'].apply(lambda x: x.year)
payments['month'] = payments['check/payment_date'].apply(lambda x: x.month)

# %%
payments.head()
# Out:
#                                 check/payment_date commitmt_item_name  \
# vendor_name
# 3M COMPANY                              2014-01-02        Inventories
# 3M COMPANY                              2014-01-02        Inventories
# 3M COMPANY                              2014-01-02        Inventories
# AGS SAFETY & SUPPLY                     2014-01-02        Inventories
# AMERICAN EUROCOPTER CORPORATION         2014-01-02        Inventories
#
#                                         dept._descrptn  invoice_net_amt  \
# vendor_name
# 3M COMPANY                       Street Transportation           -34.78
# 3M COMPANY                       Street Transportation           -69.55
# 3M COMPANY                       Street Transportation           -77.00
# AGS SAFETY & SUPPLY                       Public Works             0.01
# AMERICAN EUROCOPTER CORPORATION                 Police            -0.79
#
#                                 year_month  year  month
# vendor_name
# 3M COMPANY                          201401  2014      1
# 3M COMPANY                          201401  2014      1
# 3M COMPANY                          201401  2014      1
# AGS SAFETY & SUPPLY                 201401  2014      1
# AMERICAN EUROCOPTER CORPORATION     201401  2014      1

# %%
payments.groupby('year')['invoice_net_amt'].sum().reset_index().style.format({'invoice_net_amt': '${0:,.0f}'})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_8ff5f93e_9cfa_11e9_ba03_9cb6d0ea6ad2" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >year</th>
#         <th class="col_heading level0 col1" >invoice_net_amt</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_8ff5f93e_9cfa_11e9_ba03_9cb6d0ea6ad2level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_8ff5f93e_9cfa_11e9_ba03_9cb6d0ea6ad2row0_col0" class="data row0 col0" >2014</td>
#         <td id="T_8ff5f93e_9cfa_11e9_ba03_9cb6d0ea6ad2row0_col1" class="data row0 col1" >$1,953,571,475</td>
#     </tr>    <tr>
#         <th id="T_8ff5f93e_9cfa_11e9_ba03_9cb6d0ea6ad2level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_8ff5f93e_9cfa_11e9_ba03_9cb6d0ea6ad2row1_col0" class="data row1 col0" >2015</td>
#         <td id="T_8ff5f93e_9cfa_11e9_ba03_9cb6d0ea6ad2row1_col1" class="data row1 col1" >$1,878,188,711</td>
#     </tr>    <tr>
#         <th id="T_8ff5f93e_9cfa_11e9_ba03_9cb6d0ea6ad2level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_8ff5f93e_9cfa_11e9_ba03_9cb6d0ea6ad2row2_col0" class="data row2 col0" >2016</td>
#         <td id="T_8ff5f93e_9cfa_11e9_ba03_9cb6d0ea6ad2row2_col1" class="data row2 col1" >$2,188,409,617</td>
#     </tr>    <tr>
#         <th id="T_8ff5f93e_9cfa_11e9_ba03_9cb6d0ea6ad2level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_8ff5f93e_9cfa_11e9_ba03_9cb6d0ea6ad2row3_col0" class="data row3 col0" >2017</td>
#         <td id="T_8ff5f93e_9cfa_11e9_ba03_9cb6d0ea6ad2row3_col1" class="data row3 col1" >$2,192,127,991</td>
#     </tr>    <tr>
#         <th id="T_8ff5f93e_9cfa_11e9_ba03_9cb6d0ea6ad2level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_8ff5f93e_9cfa_11e9_ba03_9cb6d0ea6ad2row4_col0" class="data row4 col0" >2018</td>
#         <td id="T_8ff5f93e_9cfa_11e9_ba03_9cb6d0ea6ad2row4_col1" class="data row4 col1" >$2,619,813,268</td>
#     </tr></tbody>
# </table>

# %%
sns.set(rc={'figure.figsize':(15,5)})

ax = sns.lineplot(x=payments_yr_month.iloc[:,0], \
                  y=payments_yr_month.iloc[:,2], \
                  data=payments_yr_month)

plt.title("Year Over Year Payments",fontsize=20)
plt.xlabel("Year",fontsize=14)
plt.ylabel("Payments in Millions($)",fontsize=14)

ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/1000000), ',')))
ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(1))

# %%
sns.set(rc={'figure.figsize':(15,5)})

sns.set_context('talk')
# sns.set_context('paper')
# sns.set_context('poster')

plt.ylim(0,700000000)

ax = sns.lineplot(x=payments_yr_month.iloc[:,1], \
                  y=payments_yr_month.iloc[:,2], \
                  hue=payments_yr_month.iloc[:,0], \
                  data=payments_yr_month)

# plt.title("Payments By Month Of The Year")
plt.xlabel("Month")
plt.ylabel("Payments in Millions($)")

ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),ncol=5)

ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/1000000), ',')))
ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(1))
# plt.savefig("visualizations/month_over_month.png")

# %%
sns.set(rc={'figure.figsize':(15,5)})

sns.set_context("notebook", font_scale=1.4)
plt.ylim(0,700000000)

ax = sns.lineplot(x=payments.groupby('year_month')['invoice_net_amt'].sum().reset_index().iloc[:,0], \
                  y=payments.groupby('year_month')['invoice_net_amt'].sum().reset_index().iloc[:,1], \
                  data=payments.groupby('year_month')['invoice_net_amt'].sum().reset_index())

# plt.title("Payments By Year/Month",fontsize=20)
plt.xlabel("Year/Month", labelpad=15)
plt.ylabel("Payments in Millions($)",labelpad=10)

ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/1000000), ',')))
ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(6))
plt.savefig("visualizations/payments_by_year_month.png")

# %%
sns.set(rc={'figure.figsize':(15,5)})

sns.set_context("talk")
# sns.set_context("notebook", font_scale=1.3)


plt.ylim(0,700000000)

ax = sns.lineplot(x=payments.groupby('year_month')['invoice_net_amt'].sum().reset_index().iloc[:,0], \
                  y=payments.groupby('year_month')['invoice_net_amt'].sum().reset_index().iloc[:,1], \
                  data=payments.groupby('year_month')['invoice_net_amt'].sum().reset_index(),
                 color='coral')

# plt.title("Payments By Year/Month",fontsize=20)
plt.xlabel("Year/Month", labelpad=15)
plt.ylabel("Payments in Millions($)",labelpad=10)

ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/1000000), ',')))
ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(6))
# plt.savefig("visualizations/payments_by_year_month.png")
